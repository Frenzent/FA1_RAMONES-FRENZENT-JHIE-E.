# %% [markdown]
# #  **Start the Python interpreter and use it as a calculator.**

# %% [markdown]
# # 2. How many miles are there in 10 kilometers? Hint: there are 1.61 kilometers in a mile.

# %%
# x = km
x = 10

# y = mile per km
y = 0.621371

miles = x * y

print('%d kilometers is equal to %0.2f miles.' %(x,miles))
# Out:
# 10 kilometers is equal to 6.21 miles.

# %%
# TO GET THE INPUT OF THE USER

#for the input of the user 
x = float(input('Enter the distance value of the kilometer(s):'))

# conversion factor of miles and kilometers
y = 0.621371

# to calculate the miles from the input of the user:
mile = x * y

# to print the output of the code:
print('%d kilometers is equal to %0.4f miles.' %(x, mile))
# Out:
# Enter the distance value of the kilometer(s): 30
# 30 kilometers is equal to 18.6411 miles.

# %% [markdown]
# # 3. If you run a 10 kilometer race in 42 minutes 42 seconds, what is your average pace (time per mile in minutes and seconds)? What is your average speed in miles per hour?

# %%
print("Exercises 1-2. Item 3\n")

# declare the minutes in the question 
mins = 42
# seconds is e 
sec = 42 * 60 + .7
hours = mins / 60


# x= kilometer per mile
# d = distance (km)
x = 1.61
d = 10 

# formula of km to miles
miles = d / x 

#formulas to get the pace and the miles per hour
pace_minutes = mins / miles
pace_sec = sec/miles
mph = miles / hours

print('Pace in mile per minutes:', pace_minutes)
print('pace in mile per seconds:', pace_sec )
print('Average speed in mph:', mph)
# Out:
# Exercises 1-2. Item 3
#
# Pace in mile per minutes: 6.7620000000000005
# pace in mile per seconds: 405.83270000000005
# Average speed in mph: 8.873114463176574

# %% [markdown]
# # input the minutes of the run

# %%
#to get the input of the user

#enter the number of minutes of run
mins = float(input("enter the minutes of the run:"))
sec = float(input('enter the seconds of the run:'))
seconds = sec/60
minutes_seconds = mins + seconds
seconds_seconds = minutes + seconds

#conversion of minutes to hours
hours = mins / 60 

#conversion of minutes to seconds
minutes = mins * 60 

#x= kilometer per mile
# d = distance in (km)
x = 1.61
d = 10 

# formula of km to miles
miles = d / x

#formulas to get the pace and the miles per hour
pace_minutes = minutes_seconds/ miles
pace_seconds = seconds_seconds /miles
mph = miles / hours

print('Pace in minutes per mile:', pace_minutes)
print('Pace in mile per seconds:', pace_seconds)
print('Average speed in mph:', mph)
# Out:
# enter the minutes of the run: 50
# enter the seconds of the run: 52
# Pace in minutes per mile: 8.189533333333335
# Pace in mile per seconds: 579.7395333333334
# Average speed in mph: 7.453416149068322
